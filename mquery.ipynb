# %%
import requests
import csv

# %%
def query_food_database(ingredient_name, app_id, app_key):
    url = "https://api.edamam.com/api/food-database/v2/parser"
    params = {
        "ingr": ingredient_name,
        "app_id": app_id,
        "app_key": app_key
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print("Error:", response.status_code)
        return None

def query_food_nutrients(food_id, app_id, app_key, uri):
    url = "https://api.edamam.com/api/food-database/v2/nutrients"
    params = {
        "app_id": app_id,
        "app_key": app_key
    }
    data = {
        "ingredients": [
            {
                "quantity": 1,
                "measureURI": uri,
                "foodId": food_id
            }
        ]
    }
    response = requests.post(url, params=params, json=data)
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print("Error:", response.status_code)
        return None

# Replace 'YOUR_APP_ID' and 'YOUR_APP_KEY' with your actual app ID and app key
app_id = "f788f9ed"
app_key = "b560345ad298986662e16696f5277cb7"

# Create a list to store the data
ingredient_data = []

# Open the CSV file containing ingredient list
with open('unique_and_recipe1m_ingredients.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        ingredient_name = row['Ingredient']
        print(ingredient_name)
        
        # Query the first access point to get food ID, nutrients, and category
        data = query_food_database(ingredient_name, app_id, app_key)
        try:
            if data:
                # if hints is not empty
                if not data['hints']:
                    print("No data found for", ingredient_name)
                    print(" ")
                    continue
                food_id = data['hints'][0]['food']['foodId']
                print(food_id)
                nutrients = data['hints'][0]['food']['nutrients']
                print(nutrients)
                category = data['hints'][0]['food']['category']
                print(category)

                # if data['hints']['measures']:
                label = data['hints'][0]['measures'][0]['label']
                print(label)
                weight = data['hints'][0]['measures'][0]['weight']
                print(weight)
                uri = data['hints'][0]['measures'][0]['uri']
                print(uri)
                
                # Query the second access point to get health labels
                health_labels = []
                health_data = query_food_nutrients(food_id, app_id, app_key, uri)
                if health_data:
                    health_labels = health_data.get('healthLabels', [])
                    print(health_labels)
                    print(" ")
                
                # Append data to the list
                ingredient_data.append({
                    'ingredient_name': ingredient_name,
                    'food_id': food_id,
                    'category': category,
                    'nutrients': nutrients,
                    'health_labels': health_labels,
                    'label': label,
                    'weight': weight,
                    'uri': uri
                })
        except:
            print("No data found for", ingredient_name)
            ingredient_data.append({
                'ingredient_name': ingredient_name,
                'food_id': None,
                'category': None,
                'nutrients': None,
                'health_labels': None,
                'label': None,
                'weight': None,
                'uri': None
            })
            continue

# # Write the data to a new CSV file
# with open('ingredient_info.csv', 'w', newline='') as csvfile:
#     fieldnames = ['ingredient_name', 'food_id', 'category', 'nutrients', 'health_labels']
#     writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
#     writer.writeheader()
#     for item in ingredient_data:
#         writer.writerow({
#             'ingredient_name': item['ingredient_name'],
#             'food_id': item['food_id'],
#             'category': item['category'],
#             'nutrients': item['nutrients'],
#             'health_labels': ', '.join(item['health_labels'])
#         })
# Out:
# fresh coffee
# food_ax0a0yxbbe4hx0apiz1tla01s2w7
# {'ENERC_KCAL': 1.0, 'PROCNT': 0.12, 'FAT': 0.02, 'CHOCDF': 0.0, 'FIBTG': 0.0}
# Generic foods
# Serving
# 237.0
# http://www.edamam.com/ontologies/edamam.owl#Measure_serving
# ['FAT_FREE', 'LOW_SUGAR', 'KETO_FRIENDLY', 'VEGAN', 'VEGETARIAN', 'PESCATARIAN', 'PALEO', 'SPECIFIC_CARBS', 'DAIRY_FREE', 'GLUTEN_FREE', 'WHEAT_FREE', 'EGG_FREE', 'MILK_FREE', 'PEANUT_FREE', 'TREE_NUT_FREE', 'SOY_FREE', 'FISH_FREE', 'SHELLFISH_FREE', 'PORK_FREE', 'RED_MEAT_FREE', 'CRUSTACEAN_FREE', 'CELERY_FREE', 'MUSTARD_FREE', 'SESAME_FREE', 'LUPINE_FREE', 'MOLLUSK_FREE', 'ALCOHOL_FREE', 'NO_OIL_ADDED', 'NO_SUGAR_ADDED', 'KOSHER']
#
# fajita - size flour tortillas
# food_a9ql6pdb639bs5b2nlvbob3w0mlj
# {'ENERC_KCAL': 297.0, 'PROCNT': 8.01, 'FAT': 7.58, 'CHOCDF': 49.3, 'FIBTG': 2.4}
# Generic foods
# Whole
# 49.0
# http://www.edamam.com/ontologies/edamam.owl#Measure_unit
# ['VEGAN', 'VEGETARIAN', 'PESCATARIAN', 'DAIRY_FREE', 'EGG_FREE', 'MILK_FREE', 'PEANUT_FREE', 'TREE_NUT_FREE', 'SOY_FREE', 'FISH_FREE', 'SHELLFISH_FREE', 'PORK_FREE', 'RED_MEAT_FREE', 'CRUSTACEAN_FREE', 'CELERY_FREE', 'MUSTARD_FREE', 'SESAME_FREE', 'LUPINE_FREE', 'MOLLUSK_FREE', 'ALCOHOL_FREE', 'KOSHER']
#
# black currant cordial
# food_ba1soqaazgf8fcac1lkofahoth3n
# {}
# Packaged foods
# Gram
# 1.0
# http://www.edamam.com/ontologies/edamam.owl#Measure_gram
# ['FAT_FREE', 'LOW_SUGAR', 'KETO_FRIENDLY', 'VEGAN', 'VEGETARIAN', 'PALEO', 'DAIRY_FREE', 'GLUTEN_FREE', 'WHEAT_FREE', 'EGG_FREE', 'MILK_FREE', 'PEANUT_FREE', 'TREE_NUT_FREE', 'SOY_FREE', 'FISH_FREE', 'SHELLFISH_FREE', 'PORK_FREE', 'RED_MEAT_FREE', 'CRUSTACEAN_FREE', 'CELERY_FREE', 'MUSTARD_FREE', 'SESAME_FREE', 'LUPINE_FREE', 'MOLLUSK_FREE', 'NO_OIL_ADDED', 'NO_SUGAR_ADDED', 'KOSHER']
#
# hawaiian punch drink
# food_aprtur4bbu1w4eaisgatob6jimoa
# {'ENERC_KCAL': 28.169014084507044, 'PROCNT': 0.0, 'FAT': 0.0, 'CHOCDF': 7.042253521126761}
# Packaged foods
# Serving
# 355.0
# http://www.edamam.com/ontologies/edamam.owl#Measure_serving
# ['FAT_FREE', 'VEGAN', 'VEGETARIAN', 'PESCATARIAN', 'DAIRY_FREE', 'GLUTEN_FREE', 'WHEAT_FREE', 'EGG_FREE', 'MILK_FREE', 'PEANUT_FREE', 'TREE_NUT_FREE', 'SOY_FREE', 'FISH_FREE', 'SHELLFISH_FREE', 'PORK_FREE', 'RED_MEAT_FREE', 'CRUSTACEAN_FREE', 'CELERY_FREE', 'MUSTARD_FREE', 'SESAME_FREE', 'LUPINE_FREE', 'MOLLUSK_FREE', 'ALCOHOL_FREE', 'NO_OIL_ADDED', 'KOSHER']
#
# stuffed green olive
# food_au01k5obo9mz1pa1febfibire8z8
# {'ENERC_KCAL': 145.0, 'PROCNT': 1.03, 'FAT': 15.3, 'CHOCDF': 3.84, 'FIBTG': 3.3}
# Generic foods
# Serving
# 30.0
# http://www.edamam.com/ontologies/edamam.owl#Measure_serving
# ['KETO_FRIENDLY', 'VEGAN', 'VEGETARIAN', 'PESCATARIAN', 'PALEO', 'SPECIFIC_CARBS', 'DAIRY_FREE', 'GLUTEN_FREE', 'WHEAT_FREE', 'EGG_FREE', 'MILK_FREE', 'PEANUT_FREE', 'TREE_NUT_FREE', 'SOY_FREE', 'FISH_FREE', 'SHELLFISH_FREE', 'PORK_FREE', 'RED_MEAT_FREE', 'CRUSTACEAN_FREE', 'CELERY_FREE', 'MUSTARD_FREE', 'SESAME_FREE', 'LUPINE_FREE', 'MOLLUSK_FREE', 'ALCOHOL_FREE', 'NO_OIL_ADDED', 'NO_SUGAR_ADDED', 'KOSHER']
#
# saga blue cheese
# food_ao35kxmb5lh3lpaeaxh9ka2vfaf4
# {'ENERC_KCAL': 353.0, 'PROCNT': 21.4, 'FAT': 28.7, 'CHOCDF': 2.34, 'FIBTG': 0.0}
# Generic foods
# Serving
# 30.0
# http://www.edamam.com/ontologies/edamam.owl#Measure_serving
# ['KETO_FRIENDLY', 'VEGETARIAN', 'PESCATARIAN', 'SPECIFIC_CARBS', 'GLUTEN_FREE', 'WHEAT_FREE', 'EGG_FREE', 'PEANUT_FREE', 'TREE_NUT_FREE', 'SOY_FREE', 'FISH_FREE', 'SHELLFISH_FREE', 'PORK_FREE', 'RED_MEAT_FREE', 'CRUSTACEAN_FREE', 'CELERY_FREE', 'MUSTARD_FREE', 'SESAME_FREE', 'LUPINE_FREE', 'MOLLUSK_FREE', 'ALCOHOL_FREE', 'NO_OIL_ADDED', 'NO_SUGAR_ADDED', 'KOSHER']
#
# recipe amaretto frosting
# food_b46xvc4a8bojtpapnqkhcaeobwzy
# {'ENERC_KCAL': 308.0, 'PROCNT': 0.1, 'FAT': 0.3, 'CHOCDF': 32.2, 'FIBTG': 0.0}
# Generic foods
# Serving
# 50.0
# http://www.edamam.com/ontologies/edamam.owl#Measure_serving
# ['FAT_FREE', 'VEGAN', 'VEGETARIAN', 'PESCATARIAN', 'PALEO', 'DAIRY_FREE', 'GLUTEN_FREE', 'WHEAT_FREE', 'EGG_FREE', 'MILK_FREE', 'PEANUT_FREE', 'TREE_NUT_FREE', 'SOY_FREE', 'FISH_FREE', 'SHELLFISH_FREE', 'PORK_FREE', 'RED_MEAT_FREE', 'CRUSTACEAN_FREE', 'CELERY_FREE', 'MUSTARD_FREE', 'SESAME_FREE', 'LUPINE_FREE', 'MOLLUSK_FREE', 'NO_OIL_ADDED', 'KOSHER']
#
# fat - free butterscotch ice cream topping
# food_bhnrqhbangozxza4114gkb6fihyw
# {'ENERC_KCAL': 216.0, 'PROCNT': 1.21, 'FAT': 0.0, 'CHOCDF': 57.0, 'FIBTG': 0.0}
# Generic foods
# Serving
# 205.0
# http://www.edamam.com/ontologies/edamam.owl#Measure_serving
# ['FAT_FREE', 'VEGETARIAN', 'PESCATARIAN', 'GLUTEN_FREE', 'WHEAT_FREE', 'EGG_FREE', 'PEANUT_FREE', 'TREE_NUT_FREE', 'SOY_FREE', 'FISH_FREE', 'SHELLFISH_FREE', 'PORK_FREE', 'RED_MEAT_FREE', 'CRUSTACEAN_FREE', 'CELERY_FREE', 'MUSTARD_FREE', 'SESAME_FREE', 'LUPINE_FREE', 'MOLLUSK_FREE', 'ALCOHOL_FREE', 'NO_OIL_ADDED', 'KOSHER']
#
# bread and butter pickle
# food_bd06g1pbfdev9ja50blv6a5524ye
# {'ENERC_KCAL': 91.0, 'PROCNT': 0.58, 'FAT': 0.41, 'CHOCDF': 21.2, 'FIBTG': 1.0}
# Generic foods
# Whole
# 25.0
# http://www.edamam.com/ontologies/edamam.owl#Measure_unit
# ['FAT_FREE', 'KETO_FRIENDLY', 'VEGAN', 'VEGETARIAN', 'PESCATARIAN', 'PALEO', 'DAIRY_FREE', 'GLUTEN_FREE', 'WHEAT_FREE', 'EGG_FREE', 'MILK_FREE', 'PEANUT_FREE', 'TREE_NUT_FREE', 'SOY_FREE', 'FISH_FREE', 'SHELLFISH_FREE', 'PORK_FREE', 'RED_MEAT_FREE', 'CRUSTACEAN_FREE', 'CELERY_FREE', 'SESAME_FREE', 'LUPINE_FREE', 'MOLLUSK_FREE', 'ALCOHOL_FREE', 'NO_OIL_ADDED', 'NO_SUGAR_ADDED', 'KOSHER']
#
# mild red onions
# food_bmrvi4ob4binw9a5m7l07amlfcoy
# {'ENERC_KCAL': 40.0, 'PROCNT': 1.1, 'FAT': 0.1, 'CHOCDF': 9.34, 'FIBTG': 1.7}
# Generic foods
# Serving
# 32.0
# http://www.edamam.com/ontologies/edamam.owl#Measure_serving

# %%
# Specify the file name for the new CSV file
output_file = 'ingredient_info.csv'

# Specify the field names for the CSV file
fieldnames = ['ingredient_name', 'food_id', 'category', 'nutrients', 'health_labels', 'label', 'weight', 'uri']

# Write the data to the new CSV file
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    # Write the header row
    writer.writeheader()
    
    # Write each item in ingredient_data to the CSV file
    for item in ingredient_data:
        writer.writerow({
            'ingredient_name': item['ingredient_name'],
            'food_id': item['food_id'],
            'category': item['category'],
            'nutrients': item['nutrients'],
            'health_labels': ', '.join(item['health_labels']),
            'label': item['label'],
            'weight': item['weight'],
            'uri': item['uri']
        })

print(f"Data has been saved to {output_file}")
# Out:
# Data has been saved to ingredient_info.csv
